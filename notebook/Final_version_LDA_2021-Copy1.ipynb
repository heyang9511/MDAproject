# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Topic-Modeling-with-Latent-Dirichlet-Allocation-(LDA)" data-toc-modified-id="Topic-Modeling-with-Latent-Dirichlet-Allocation-(LDA)-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Topic Modeling with Latent Dirichlet Allocation (LDA)</a></span><ul class="toc-item"><li><span><a href="#What-is-topic-modeling?" data-toc-modified-id="What-is-topic-modeling?-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>What is topic modeling?</a></span></li><li><span><a href="#Theoretical-Overview-of-LDA" data-toc-modified-id="Theoretical-Overview-of-LDA-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Theoretical Overview of LDA</a></span></li></ul></li><li><span><a href="#Proposed-Research-Question" data-toc-modified-id="Proposed-Research-Question-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Proposed Research Question</a></span></li><li><span><a href="#Set-Up" data-toc-modified-id="Set-Up-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Set Up</a></span></li><li><span><a href="#Version-Checking" data-toc-modified-id="Version-Checking-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Version Checking</a></span></li><li><span><a href="#Data-Loading" data-toc-modified-id="Data-Loading-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Data Loading</a></span></li><li><span><a href="#Data-Cleaning" data-toc-modified-id="Data-Cleaning-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Data Cleaning</a></span></li><li><span><a href="#Preprocessing" data-toc-modified-id="Preprocessing-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Preprocessing</a></span></li><li><span><a href="#Prepare-Dictionary-and-Corpus" data-toc-modified-id="Prepare-Dictionary-and-Corpus-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Prepare Dictionary and Corpus</a></span></li><li><span><a href="#Further-Cleaning" data-toc-modified-id="Further-Cleaning-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Further Cleaning</a></span></li><li><span><a href="#Grid-Search-for-Optimal-Number-of-Topics" data-toc-modified-id="Grid-Search-for-Optimal-Number-of-Topics-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Grid Search for Optimal Number of Topics</a></span></li><li><span><a href="#Updated-LDA-Model" data-toc-modified-id="Updated-LDA-Model-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Updated LDA Model</a></span><ul class="toc-item"><li><span><a href="#Obtaining-topic-distributions-for-all-documents" data-toc-modified-id="Obtaining-topic-distributions-for-all-documents-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Obtaining topic distributions for all documents</a></span></li><li><span><a href="#LDA-Model-Topic-Word-Cloud" data-toc-modified-id="LDA-Model-Topic-Word-Cloud-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>LDA Model Topic Word Cloud</a></span></li><li><span><a href="#Word-Count-and-Importance" data-toc-modified-id="Word-Count-and-Importance-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Word Count and Importance</a></span></li><li><span><a href="#LDA-Model-Interactive-Topic-Visualization" data-toc-modified-id="LDA-Model-Interactive-Topic-Visualization-11.4"><span class="toc-item-num">11.4&nbsp;&nbsp;</span>LDA Model Interactive Topic Visualization</a></span></li><li><span><a href="#Dominant-Topics-for-each-assembly-speech" data-toc-modified-id="Dominant-Topics-for-each-assembly-speech-11.5"><span class="toc-item-num">11.5&nbsp;&nbsp;</span>Dominant Topics for each assembly speech</a></span></li><li><span><a href="#Dominant-Topic-Percentage" data-toc-modified-id="Dominant-Topic-Percentage-11.6"><span class="toc-item-num">11.6&nbsp;&nbsp;</span>Dominant Topic Percentage</a></span></li><li><span><a href="#LDA-Topic-Weights-for-each-Topic" data-toc-modified-id="LDA-Topic-Weights-for-each-Topic-11.7"><span class="toc-item-num">11.7&nbsp;&nbsp;</span>LDA Topic Weights for each Topic</a></span></li><li><span><a href="#LDA-Topic-Distribution-from-1970-to-2018" data-toc-modified-id="LDA-Topic-Distribution-from-1970-to-2018-11.8"><span class="toc-item-num">11.8&nbsp;&nbsp;</span>LDA Topic Distribution from 1970 to 2018</a></span></li><li><span><a href="#LDA-Topic-Distribution-across-different-countries" data-toc-modified-id="LDA-Topic-Distribution-across-different-countries-11.9"><span class="toc-item-num">11.9&nbsp;&nbsp;</span>LDA Topic Distribution across different countries</a></span></li><li><span><a href="#Topic-Distribution-Plot" data-toc-modified-id="Topic-Distribution-Plot-11.10"><span class="toc-item-num">11.10&nbsp;&nbsp;</span>Topic Distribution Plot</a></span></li><li><span><a href="#Stacked-Area-Visualization" data-toc-modified-id="Stacked-Area-Visualization-11.11"><span class="toc-item-num">11.11&nbsp;&nbsp;</span>Stacked Area Visualization</a></span></li></ul></li><li><span><a href="#LDA-Mallet" data-toc-modified-id="LDA-Mallet-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>LDA Mallet</a></span><ul class="toc-item"><li><span><a href="#Optimal-Number-of-Topics-for-Mallet-Model" data-toc-modified-id="Optimal-Number-of-Topics-for-Mallet-Model-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span>Optimal Number of Topics for Mallet Model</a></span></li><li><span><a href="#Word-Cloud" data-toc-modified-id="Word-Cloud-12.2"><span class="toc-item-num">12.2&nbsp;&nbsp;</span>Word Cloud</a></span></li><li><span><a href="#word-count-and-importance" data-toc-modified-id="word-count-and-importance-12.3"><span class="toc-item-num">12.3&nbsp;&nbsp;</span>word count and importance</a></span></li><li><span><a href="#Interactive-Topic-Visualization" data-toc-modified-id="Interactive-Topic-Visualization-12.4"><span class="toc-item-num">12.4&nbsp;&nbsp;</span>Interactive Topic Visualization</a></span></li><li><span><a href="#Dominant-Topics-for-each-countries" data-toc-modified-id="Dominant-Topics-for-each-countries-12.5"><span class="toc-item-num">12.5&nbsp;&nbsp;</span>Dominant Topics for each countries</a></span></li><li><span><a href="#Dominant-Topics-Distribution-Across-Speeches" data-toc-modified-id="Dominant-Topics-Distribution-Across-Speeches-12.6"><span class="toc-item-num">12.6&nbsp;&nbsp;</span>Dominant Topics Distribution Across Speeches</a></span></li><li><span><a href="#Dominant-Topic-Overall-Percentages" data-toc-modified-id="Dominant-Topic-Overall-Percentages-12.7"><span class="toc-item-num">12.7&nbsp;&nbsp;</span>Dominant Topic Overall Percentages</a></span></li><li><span><a href="#Topic-Distribution-From-1970---2018" data-toc-modified-id="Topic-Distribution-From-1970---2018-12.8"><span class="toc-item-num">12.8&nbsp;&nbsp;</span>Topic Distribution From 1970 - 2018</a></span></li><li><span><a href="#Topic-Distribution-across-different-country" data-toc-modified-id="Topic-Distribution-across-different-country-12.9"><span class="toc-item-num">12.9&nbsp;&nbsp;</span>Topic Distribution across different country</a></span></li></ul></li><li><span><a href="#Stacked-Area-Visualization" data-toc-modified-id="Stacked-Area-Visualization-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Stacked Area Visualization</a></span></li></ul></div>

# %%
#import sys
#!conda install --yes --prefix {sys.prefix} watermark

# %%
#%load_ext watermark
#%watermark -a 'Yang He' -v -p numpy,matplotlib,seaborn

# %% [markdown]
# ## Topic Modeling with Latent Dirichlet Allocation (LDA)

# %% [markdown]
# ### What is topic modeling?
#
# Topic modeling ensentially is a way or suite of techiques to identify latent themes in a corpus, which is a group of variety of documents from newspaper articles, tweets, and speech etc. to any kind of text of interest. The initial goal to achieve by employing the LDA topic modeling is to extract the main topics from humongous groups of text that human can't possibly read by themselves in a short period of time.

# %% [markdown]
# ### Theoretical Overview of LDA

# %% [markdown]
# <div>
# <img src="attachment:image-5.png" width="600"/>
# </div>

# %% [markdown]
# LDA is a developed by computer scientist David Blei who was interested to see whether the computer could be trained using a variety of Bayesian learning to detect themes in scientific abstracts from the science journal. The LDA for topic modeling is a probabilistic generative model that assumes that each underlying topic is a mixture over a set of words, and each document is a mixture over a different set of topic probabilities.
#
# Given the *M* number of documents, *N* number of words, and prior arbitrary *K* numebr of topics, the model can yield a distribution of words for each topic *K* and the distribution of topics for each document.

# %% [markdown]
# ## Proposed Research Question

# %% [markdown]
# Is there a change , a trend you can observe in the different speeches delivered by our political leaders ? More importantly, are these speeches exhibiting a changing view on climate change ? If not, what are the main topics ? (peace, financial stability, poverty,...)

# %% [markdown]
# ## Set Up

# %%
# conda update smart_open
import smart_open
smart_open.open = smart_open.smart_open
## Given the problematic version of new genism, I will use the older version which supports genism.model.wrapper function

# %%
# General
import sys
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# Gensim
import gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# Interactive Visualization
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis

# Spacy
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import spacy

# Warning Supression
import warnings
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category = DeprecationWarning)

# %% [markdown]
# ## Version Checking

# %%
print('\n'.join(f'{m.__name__}=={m.__version__}' for m in globals().values() if getattr(m, '__version__', None)))

# %%
print('Python Version: %s' % (sys.version))

# %% [markdown]
# - *json==2.0.9*
# - *numpy==1.20.2*
# - *pandas==1.2.2*
# - *seaborn==0.11.1*
# - *gensim==3.8.0*
# - *spacy==3.0.6*
# - *pyLDAvis==3.3.1*

# %%
## ALl module installed in jupyter notebook
# !pip freeze

# %% [markdown]
# ## Data Loading
#
# The data we used for this project is called *All Trans.xlsx*, and there is a null instance called `.DS`， which is a non-inforamtive by product of data transformation from PDF to tabular data frame. Hence, we will drop that from our model. The original documents are available [here](https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/0TJX8Y)

# %%
df = pd.read_excel('/Users/yuanyuanli/Desktop/KU Leuven/2020-2021/Morden Data Analytics/Project/dataverse_files/All Trans.xlsx', index_col = 0)
df = df[df.country != '.DS']

# %%
df_un = df.copy()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('white')

# %%
# order country counts per country and get the index
order = df_un.country.value_counts(ascending=True).index
plt.figure(figsize=(40,50))
sns.countplot(y='country', data=df_un, orient='h', order=order)

# %% [markdown]
# ## Data Cleaning
#
# We will use regular expressions to
# - Clean out any unfavorable characters in our dataset
# - Remove all roman numerical characters
# - Delete new line characters from data transformation ( *\n*  and  *\t* )
# - Add space between each capitalized word
#
# then preview what the data looks like after the cleaning.

# %%
df_trpt = df_un[['transcript']]
data = df_trpt['transcript'].values.tolist()

# %%
# Use Regex to remove all characters except letters and space
import re
data = [re.sub(r'[^a-zA-Z ]+', '', str(sentence)) for sentence in data] 

# Remove roman numerical characters
data = [re.sub(r'(?=\b[MCDXLVI]{1,6}\b)M{0,4}(?:CM|CD|D?C{0,3})(?:XC|XL|L?X{0,3})(?:IX|IV|V?I{0,3})', '', str(sentence)) for sentence in data]

# Grouping Multiple Patterns
data = [re.sub(r'[,@\'?\.$%_]', '', str(sentence)) for sentence in data]

# Remove new line characters
data = [re.sub(r'\s+', ' ', str(sentence)) for sentence in data]

# Removing a Single Character
data = [re.sub(r'\s+[a-zA-Z]\s+', ' ', str(sentence)) for sentence in data]

# Adding space between each capitalized word
p = re.compile(r'(\S)([A-Z])')
data = [re.sub(p, r"\1 \2", str(sentence)) for sentence in data]

# %%
# Preview the first list of the cleaned data
from pprint import pprint
pprint(data[:1])

# %% [markdown]
# ## Preprocessing
# After successfully cleaning our data, we will proceed to each step of text data preprocessing:
#
# - **Stop word removal**: To obtain a better and more differentiable topics, it is crucial to prune all non-informative common writing words from all documents
# - **Tokenization**: Spliting the sentences into words, removing punctuation, and ignoring tokens that are too short. Additionally, we employed `deacc=True` to remove potential accents
# - **Lemmatization**: lemmatization is the reduction of words to their root form, that is their lemma. For instance, words “used”, “using”, “uses” words are all converted to “use”.
# - **Ngrams implementation**: These are helpful to build given they account for word co-occurrences. This procedure extracts sequence of ‘n’ words that occur frequently in the corpus. Here we implement bi-grams and tri-grams that mean 2 words and 3 words in sequence respectively. (bi-gram: Poisson_Process; tri-gram: central_limit_theorem)
# - **Speech of tag selection**: spaCy first tokenizes the text to produce a Doc object, then processed it in various steps as a processing pipeline. The pipeline is used by the default models consists of a tagger, but we will disable the parser and new due to unnecessary computation. Lastly, we will check part of speech tag of each token and keep only the nouns, adjectives, verbs, and adverbs for further model building.

# %%
import nltk
# nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])

# %%
# Build the bigram and trigrams
bigram = gensim.models.Phrases(data, min_count=5, threshold=100) 
trigram = gensim.models.Phrases(bigram[data], threshold=100)  

bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# %%
#import spacy
#from spacy.cli import download
#spacy.load('en_core_web_sm')

# %%
# only need tagger, no need for parser and named entity recognizer, for faster implementation
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
def process_words(texts, stop_words=stop_words, allowed_tags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    
    """Convert a document into a list of lowercase tokens, build bigrams-trigrams, implement lemmatization"""
    
    # remove stopwords, short tokens, and letter accents 
    texts = [[word for word in simple_preprocess(str(doc), deacc=True, min_len=3) if word not in stop_words] for doc in texts]
    
    # bi-gram and tri-gram implementation
    texts = [bigram_mod[doc] for doc in texts]
    texts = [trigram_mod[bigram_mod[doc]] for doc in texts]
    
    texts_out = []

    # implement lemmatization and filter out unwanted part of speech tags
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_tags])
    
    # remove stopwords and short tokens again after lemmatization
    texts_out = [[word for word in simple_preprocess(str(doc), deacc=True, min_len=3) if word not in stop_words] for doc in texts_out]    
    
    return texts_out

# %%
# Preview the data 
data_ready = process_words(data)  
data_ready[0]

# %% [markdown]
# Now the output `data_ready` is a list of strings for each speech document ready for further model buidling process

# %% [markdown]
# ##  Prepare Dictionary and Corpus
#
# Now we have preprocessed result `data_ready`, we will step into the moded-building procedure. The LDA model requires a dictionary and corpus as part of model computation. Dictionary contains ids for each of unique words, corpus on the other hand is a bag of word, which comprised of list of lists that contains tuples for each unique word id and corresponding frequency.
#
# However, different types of documents will utilize different style of writings, and some words will only serve as a general writing purpose. In order to enhance topic differentiability, we will count the frequencies of preprocessed words to perform further cleaning.

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_ready)

print('Total Vocabulary Size:', len(id2word))

# %%
# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in data_ready]

# %%
dict_corpus = {}

for i in range(len(corpus)):
  for index, freq in corpus[i]:
    if id2word[index] in dict_corpus:
      dict_corpus[id2word[index]] += freq
    else:
       dict_corpus[id2word[index]] = freq

# %%
dict_df = pd.DataFrame.from_dict(dict_corpus, orient='index', columns=['freq'])

# %%
plt.figure(figsize=(10,8))
sns.distplot(dict_df['freq'], bins=100);

# %%
dict_df.sort_values('freq', ascending=False).head(60)

# %% [markdown]
# ## Further Cleaning
#
# From the frequency table, we can see that the words above frequency of 26000 are more likely to be general words given the context. Hence, we will extend our stops word collection by adding words above frequency of 26000 and repeat preprocessing pipeline. Lastly as previous procedure, we will create dictionary and corpus for the LDA model.

# %%
extension = dict_df[dict_df.freq > 26000].index.tolist()

# %%
# add high frequency words to stop words list
stop_words.extend(extension)
# rerun the process_words function
data_ready = process_words(data)
# recreate Dictionary
id2word = corpora.Dictionary(data_ready)
print('Total Vocabulary Size:', len(id2word))

# %% [markdown]
# After we successfully cleaned the high frequency words, more words have appeared from the dictionary.

# %%
# Create Corpus: Term Document Frequency
corpus = [id2word.doc2bow(text) for text in data_ready]

# %% [markdown]
# ## Grid Search for Optimal Number of Topics
#
# LDA is an unsupervised machine learning technique, which means that one need to specify *K* number of topics prior to model building. There is various way to find optimal number of topics, For our approach, we used coherence score, which is bounded by 0 and 1, that is *Coherence Score* $\in [0, 1]$ as our criterion to train our LDA model to find number of topics in a grid of 2 to 20 topics with a step of 2, then pick the one that yields relative high coherence score and abide the law of Occam's razor. After the desired K is chosen, we will incorporate it for our final LDA model.

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model=gensim.models.ldamodel.LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, 
                                              random_state = 100, update_every = 1, chunksize = 100, passes = 10, alpha = 'auto', per_word_topics=True)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_ready, start=2, limit=20, step=2)
# Show graph
plt.rcParams['figure.figsize'] = [10, 5]
import matplotlib.pyplot as plt
limit=20; start=2; step=2;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print('Num Topics =', m, ' has Coherence Value of', round(cv, 4))

# %% [markdown]
# ## Updated LDA Model
#
# From above, we can see that the model with 6 topics and 14 topics yield high coherence score. Given the fact the more topics can lead to topic repetition and incomprehensible. Hence we will take 6 topics for our LDA model

# %%
# Build LDA Model
from pprint import pprint
import warnings
warnings.filterwarnings('ignore')
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus, id2word=id2word, num_topics = 6, 
                                            random_state = 100, update_every = 1, chunksize = 100, passes = 14, alpha = 'auto', per_word_topics=True) # Here we selected 5 topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]

# %%
# Compute perplexity
print('Perplexity: ', lda_model.log_perplexity(corpus))

# Compute coherence score
from gensim.models import CoherenceModel
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_ready, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('Coherence Score: ', coherence_lda)

# %% [markdown]
# ### Obtaining topic distributions for all documents
#
# Next we will need to find the distribution of topics for each documents. After we have obtained them, we will extract the most dominant topics. Next our goal is to get the most top 20 significant words for corresponding topic ID.

# %%
lda_tm_results = [lda_model.get_document_topics(item, minimum_probability=0.0) for item in corpus]

# %%
lda_tm_results

# %%
lda_corpus_topics = [sorted(topics, key=lambda record: -record[1])[0] for topics in lda_tm_results]
lda_corpus_topics

# %%
lda_model.num_topics

# %%
lda_topics = [[(term, round(wt, 3)) for term, wt in lda_model.show_topic(n, topn=20)] for n in range(0, lda_model.num_topics)]
lda_topics

# %% [markdown]
# We then will create a dataframe for the words-topic matrix

# %%
lda_topics_df = pd.DataFrame([[term for term, wt in topic] for topic in lda_topics], columns = ['Key_words'+str(i) for i in range(1, 21)],
                         index=['Topic '+str(t) for t in range(1, lda_model.num_topics+1)]).T
lda_topics_df.head()

# %% [markdown]
# Also we can preview all the key words for each topic

# %%
pd.set_option('display.max_colwidth', -1)

lda_topics_df = pd.DataFrame([', '.join([term for term, wt in topic]) for topic in lda_topics], columns = ['Key_Words_per_Topic'],
                         index=['Topic'+str(t) for t in range(1, lda_model.num_topics+1)] )
lda_topics_df

# %% [markdown]
# ### LDA Model Topic Word Cloud

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)

# %%
plt.rcParams['figure.figsize'] = [20, 10]

# %%
# Create subplots for each topic
for i in range(lda_model.num_topics): #number of topics

    wc.generate(text=lda_topics_df["Key_Words_per_Topic"][i])
    
    plt.subplot(2, 3, i+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(lda_topics_df.index[i])

plt.show()

# %% [markdown]
# ### Word Count and Importance

# %%
from collections import Counter
import matplotlib.colors as mcolors
topics = lda_model.show_topics(formatted=False)
data_flat = [w for w_list in data_ready for w in w_list]
counter = Counter(data_flat)

out = []
for i, topic in topics:
    for word, weight in topic:
        out.append([word, i , weight, counter[word]])

df = pd.DataFrame(out, columns=['word', 'topic_id', 'importance', 'word_count'])        

# Plot Word Count and Weights of Topic Keywords
fig, axes = plt.subplots(2, 3, figsize=(16,10), sharey=True, dpi=160)
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]
for i, ax in enumerate(axes.flatten()):
    ax.bar(x='word', height="word_count", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.5, alpha=0.3, label='Word Count')
    ax_twin = ax.twinx()
    ax_twin.bar(x='word', height="importance", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.2, label='Weights')
    ax.set_ylabel('Word Count', color=cols[i])
    ax_twin.set_ylim(0, 0.030); ax.set_ylim(0, 3500)
    ax.set_title('Topic: ' + str(i), color=cols[i], fontsize=16)
    ax.tick_params(axis='y', left=False)
    ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
    ax.legend(loc='upper left'); ax_twin.legend(loc='upper right')

fig.tight_layout(w_pad=2)    
fig.suptitle('Word Count and Importance of Topic Keywords', fontsize=22, y=1.05)    
plt.show()

# %% [markdown]
# Number of Documents per topic

# %%
def topics_per_document(model, corpus, start=0, end=1):
    corpus_sel = corpus[start:end]
    dominant_topics = []
    topic_percentages = []
    for i, corp in enumerate(corpus_sel):
        topic_percs, wordid_topics, wordid_phivalues = model[corp]
        dominant_topic = sorted(topic_percs, key = lambda x: x[1], reverse=True)[0][0]
        dominant_topics.append((i, dominant_topic))
        topic_percentages.append(topic_percs)
    return(dominant_topics, topic_percentages)

dominant_topics, topic_percentages = topics_per_document(model=lda_model, corpus=corpus, end=-1)            

# Distribution of Dominant Topics in Each Document
df = pd.DataFrame(dominant_topics, columns=['Document_Id', 'Dominant_Topic'])
dominant_topic_in_each_doc = df.groupby('Dominant_Topic').size()
df_dominant_topic_in_each_doc = dominant_topic_in_each_doc.to_frame(name='count').reset_index()

# Total Topic Distribution by actual weight
topic_weightage_by_doc = pd.DataFrame([dict(t) for t in topic_percentages])
df_topic_weightage_by_doc = topic_weightage_by_doc.sum().to_frame(name='count').reset_index()

# Top 3 Keywords for each Topic
topic_top3words = [(i, topic) for i, topics in lda_model.show_topics(formatted=False) 
                                 for j, (topic, wt) in enumerate(topics) if j < 3]

df_top3words_stacked = pd.DataFrame(topic_top3words, columns=['topic_id', 'words'])
df_top3words = df_top3words_stacked.groupby('topic_id').agg(', \n'.join)
df_top3words.reset_index(level=0,inplace=True)

# %%
from matplotlib.ticker import FuncFormatter

# Plot
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 10), dpi=120, sharey=True)

# Topic Distribution by Dominant Topics
ax1.bar(x='Dominant_Topic', height='count', data=df_dominant_topic_in_each_doc, width=.5, color='firebrick')
ax1.set_xticks(range(df_dominant_topic_in_each_doc.Dominant_Topic.unique().__len__()))
tick_formatter = FuncFormatter(lambda x, pos: 'Topic ' + str(x)+ '\n' + df_top3words.loc[df_top3words.topic_id==x, 'words'].values[0])
ax1.xaxis.set_major_formatter(tick_formatter)
ax1.set_title('Number of Documents by Dominant Topic', fontdict=dict(size=10))
ax1.set_ylabel('Number of Documents')
ax1.set_ylim(0, 1000)

# Topic Distribution by Topic Weights
ax2.bar(x='index', height='count', data=df_topic_weightage_by_doc, width=.5, color='steelblue')
ax2.set_xticks(range(df_topic_weightage_by_doc.index.unique().__len__()))
ax2.xaxis.set_major_formatter(tick_formatter)
ax2.set_title('Number of Documents by Topic Weightage', fontdict=dict(size=10))

plt.show()

# %% [markdown]
# ### LDA Model Interactive Topic Visualization
#  interactive graph shows the topics and relative terms. You can interactively inestigate each bubbles and get the most relevant 30 words on the right.

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()

lda_vis = gensimvis.prepare(lda_model, corpus, id2word)
lda_vis

# %%
# pyLDAvis.save_html(lda_vis,'/Users/yuanyuanli/Desktop/project_results/lda.html')

# %% [markdown]
# ### Dominant Topics for each assembly speech

# %%
# create a dataframe 
lda_corpus_topic_df = pd.DataFrame()

# get the Titles from the original dataframe
lda_corpus_topic_df['country'] = df_un.country.reset_index(drop = True)

lda_corpus_topic_df['Dominant Topic'] = [item[0]+1 for item in lda_corpus_topics]
lda_corpus_topic_df['Contribution %'] = [round(item[1]*100, 2) for item in lda_corpus_topics]
lda_corpus_topic_df['Topic Terms'] = [lda_topics_df.iloc[t[0]]['Key_Words_per_Topic'] for t in lda_corpus_topics]

lda_corpus_topic_df.head(5)

# %% [markdown]
# ### Dominant Topic Percentage

# %%
lda_dominant_topic_df = lda_corpus_topic_df.groupby('Dominant Topic').agg(
                                  Doc_Count = ('Dominant Topic', np.size),
                                  Total_Docs_Perc = ('Dominant Topic', np.size)).reset_index()

lda_dominant_topic_df['Total_Docs_Perc'] = lda_dominant_topic_df['Total_Docs_Perc'].apply(lambda row: round((row*100) / len(corpus), 2))

lda_dominant_topic_df.sort_values('Total_Docs_Perc')

# %% [markdown]
# ### LDA Topic Weights for each Topic

# %%
lda_df_weights = pd.DataFrame.from_records([{v: k for v, k in row} for row in lda_tm_results])
lda_df_weights.columns = ['Topic ' + str(i) for i in range(1,7)]
lda_df_weights

# %%
df_un['year'].reset_index(drop=True)

# %%
lda_df_weights['year'] = df_un.year.reset_index(drop=True)

# %%
lda_df_weights.head(5)

# %%
lda_df_weights['prevalent'] = lda_df_weights.drop('year', axis=1).idxmax(axis=1)

# %%
lda_df_weights.head(8)

# %%
lda_df_weights.groupby('year')['prevalent'].value_counts(normalize=True)

# %%
lda_df_dominance = lda_df_weights.groupby('year')['prevalent'].value_counts(normalize=True).unstack().fillna(0)
lda_df_dominance

# %% [markdown]
# ### LDA Topic Distribution from 1970 to 2018

# %%
lda_df_dominance_year = lda_df_weights.groupby('year')['prevalent'].value_counts(normalize=True).unstack().fillna(0).reset_index().copy()
lda_df_dominance_year.head(5)

# %%
df_melted_year = lda_df_dominance_year.melt(id_vars= 'year' , value_vars=['Topic ' + str(i) for i in [1,2, 3, 4, 5, 6]], var_name='Topic', value_name='prevelance')

# %%
df_melted_year

# %%
df_melted_year.to_excel("/Users/yuanyuanli/Desktop/project_results/topic_trend.xlsx")

# %%
sns.set_style("whitegrid")
_ = sns.lineplot(data=df_melted_year, x="year", y="prevelance", hue="Topic", style="Topic", palette='Dark2')

# %% [markdown]
# ### LDA Topic Distribution across different countries

# %%
lda_df_weights["country"] = df_un.country.reset_index(drop=True)

# %%
lda_df_weights.head(4)

# %%
lda_df_country = lda_df_weights.groupby(['country', 'year'])['prevalent'].value_counts(normalize=True).unstack().fillna(0)
lda_df_country

# %%
lda_df_country.reset_index(inplace=True)

# %%
lda_df_country

# %%
df_melted = lda_df_country.melt(id_vars=['country', 'year'], value_vars=['Topic ' + str(i) for i in [1,2,3,4,5,6]], var_name='Topic', value_name='prevelance')

# %%
df_melted.head(10)

# %% [markdown]
# ### Topic Distribution Plot

# %%
sns.relplot(x='year', y="prevelance", col="country", col_wrap=3, hue='Topic',
data=df_melted,
kind="line",
height=10,
style="Topic",
dashes=False,
ci=None,
palette='Dark2');

# %% [markdown]
# ### Stacked Area Visualization

# %%
lda_df_country

# %%
lda_df_country.set_index(['country', 'year'], inplace=True)

# %%
# set the figure size
plt.rcParams['figure.figsize'] = [10, 6]

# %%
for j in lda_df_country.index.levels[0]:
  lda_df_country.xs(j, level=0).plot.area(colormap = 'Paired')
  plt.title(j)
  plt.legend(loc='upper left')

plt.show()

# %% [markdown]
# ## LDA Mallet
#
# LDA Mallet model is another alternative algorithm for topic modeling. The most distinctive difference between gensim LDA model and LDA Mallet model is the sampling method. Usually gensim LDA model is faster, but LDA Mallet will yield more accurate result.

# %%
## Enter the directory here
mallet_path = '/Users/yuanyuanli/Desktop/mallet-2.0.8/bin/mallet'

# %% [markdown]
# ### Optimal Number of Topics for Mallet Model

# %%
import matplotlib.pyplot as plt
# Compute a list of LDA Mallet Models and corresponding Coherence Values
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=1):
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus,
                                                 num_topics=num_topics,
                                                 id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts,
                                        dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence()) 
    return model_list, coherence_values

model_list, coherence_values = compute_coherence_values(dictionary=id2word,
                                                        corpus=corpus,
                                                        texts=data_ready,
                                                        start=2, limit=30,
                                                        step=4)

# Visualize the optimal LDA Mallet Model
plt.rcParams['figure.figsize'] = [10, 5]
limit=30; start=2; step=4;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel('Num Topics')
plt.ylabel('Coherence score')
plt.legend(('coherence_values'), loc='best')
plt.show()

# %%
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=6, id2word=id2word)

# %%
# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=data_ready, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('Coherence Score: ', coherence_ldamallet)

# %%
from pprint import pprint
# display topics
pprint(ldamallet.show_topics(formatted=True))

# %%
tm_results = ldamallet[corpus]

# %%
corpus_topics = [sorted(topics, key=lambda record: -record[1])[0] for topics in tm_results]

# %%
topics = [[(term, round(wt, 3)) for term, wt in ldamallet.show_topic(n, topn=20)] for n in range(0, ldamallet.num_topics)]

# %%
topics_df = pd.DataFrame([[term for term, wt in topic] for topic in topics], columns = ['Key_words'+str(i) for i in range(1, 21)],
                         index=['Topic '+str(t) for t in range(1, ldamallet.num_topics+1)]).T
topics_df.head()

# %%
pd.set_option('display.max_colwidth', -1)

topics_df = pd.DataFrame([', '.join([term for term, wt in topic]) for topic in topics], columns = ['Key_Words_per_Topic'],
                         index=['Topic'+str(t) for t in range(1, ldamallet.num_topics+1)] )
topics_df

# %% [markdown]
# ### Word Cloud
#
# Visualizing the terms as wordclouds offers a good option to present topics. Below we create wordclouds for each topic. The font sizes of words corresponds their relative weights in the topic.

# %%
ldamallet.num_topics

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(background_color="white", colormap="Dark2_r",
               max_font_size=150, random_state=42)

# %%
plt.rcParams['figure.figsize'] = [20, 10]

# %%
# Create subplots for each topic
for i in range(6):

    wc.generate(text=topics_df["Key_Words_per_Topic"][i])
    
    plt.subplot(2, 3, i+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(topics_df.index[i])

plt.show()

# %%
from gensim.models.ldamodel import LdaModel
def convertldaMalletToldaGen(mallet_model):
    model_gensim = LdaModel(
        id2word=mallet_model.id2word, num_topics=mallet_model.num_topics,
        alpha=mallet_model.alpha) # original function has 'eta=0' argument
    model_gensim.state.sstats[...] = mallet_model.wordtopics
    model_gensim.sync_state()
    return model_gensim

# %%
ldagensim = convertldaMalletToldaGen(ldamallet)

# %% [markdown]
# ### word count and importance

# %%
from collections import Counter
topics = ldamallet.show_topics(formatted=False)
data_flat = [w for w_list in data_ready for w in w_list]
counter = Counter(data_flat)

out = []
for i, topic in topics:
    for word, weight in topic:
        out.append([word, i , weight, counter[word]])

df = pd.DataFrame(out, columns=['word', 'topic_id', 'importance', 'word_count'])        

# Plot Word Count and Weights of Topic Keywords
fig, axes = plt.subplots(2, 3, figsize=(16,10), sharey=True, dpi=160)
cols = [color for name, color in mcolors.TABLEAU_COLORS.items()]
for i, ax in enumerate(axes.flatten()):
    ax.bar(x='word', height="word_count", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.5, alpha=0.3, label='Word Count')
    ax_twin = ax.twinx()
    ax_twin.bar(x='word', height="importance", data=df.loc[df.topic_id==i, :], color=cols[i], width=0.2, label='Weights')
    ax.set_ylabel('Word Count', color=cols[i])
    ax_twin.set_ylim(0, 0.030); ax.set_ylim(0, 3500)
    ax.set_title('Topic: ' + str(i), color=cols[i], fontsize=16)
    ax.tick_params(axis='y', left=False)
    ax.set_xticklabels(df.loc[df.topic_id==i, 'word'], rotation=30, horizontalalignment= 'right')
    ax.legend(loc='upper left'); ax_twin.legend(loc='upper right')

fig.tight_layout(w_pad=2)    
fig.suptitle('Word Count and Importance of Topic Keywords', fontsize=22, y=1.05)    
plt.show()

# %% [markdown]
# ### Interactive Topic Visualization
#
#
#  interactive graph shows the topics and relative terms. You can interactively inestigate each bubbles and get the most relevant 30 words on the right.

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
pyLDAvis.enable_notebook()

lda_mallet_vis = gensimvis.prepare(ldagensim, corpus, id2word, sort_topics=False)
lda_mallet_vis

# %%
# pyLDAvis.save_html(lda_mallet_vis,'/Users/yuanyuanli/Desktop/project_results/lda_mallet.html')

# %% [markdown]
# ### Dominant Topics for each countries

# %%
# create a dataframe 
corpus_topic_df = pd.DataFrame()

# get the Titles from the original dataframe
corpus_topic_df['country'] = df_un.country

corpus_topic_df['Dominant Topic'] = [item[0]+1 for item in corpus_topics]
corpus_topic_df['Contribution %'] = [round(item[1]*100, 2) for item in corpus_topics]
corpus_topic_df['Topic Terms'] = [topics_df.iloc[t[0]]['Key_Words_per_Topic'] for t in corpus_topics]

corpus_topic_df.head(5)

# %% [markdown]
# ### Dominant Topics Distribution Across Speeches
#
# The first thing we can do is look at the overall distribution of each topic across the corpus of Assembly speeches.

# %%
dominant_topic_df = corpus_topic_df.groupby('Dominant Topic').agg(
                                  Doc_Count = ('Dominant Topic', np.size),
                                  Total_Docs_Perc = ('Dominant Topic', np.size)).reset_index()

dominant_topic_df['Total_Docs_Perc'] = dominant_topic_df['Total_Docs_Perc'].apply(lambda row: round((row*100) / len(corpus), 2))

dominant_topic_df

# %% [markdown]
# ### Dominant Topic Overall Percentages

# %%
topic_counts = dominant_topic_df[["Dominant Topic", 	"Doc_Count", "Total_Docs_Perc"]]
topic_counts.columns  = ["Dominant Topic", 	"Document Count", "Total Document Percentage"]
topic_counts

# %%
df_weights = pd.DataFrame.from_records([{v: k for v, k in row} for row in tm_results])
df_weights.columns = ['Topic ' + str(i) for i in range(1,7)]
df_weights

# %%
df_weights['year'] = df_un.year.reset_index(drop=True)

# %%
df_weights

# %%
df_weights['prevalent'] = df_weights.drop('year', axis=1).idxmax(axis=1)

# %%
df_weights.head()

# %%
df_weights.groupby('year')['prevalent'].value_counts(normalize=True)

# %%
df_dominance = df_weights.groupby('year')['prevalent'].value_counts(normalize=True).unstack().fillna(0)
df_dominance

# %% [markdown]
# ### Topic Distribution From 1970 - 2018

# %%
df_dominance_year = df_weights.groupby('year')['prevalent'].value_counts(normalize=True).unstack().fillna(0).reset_index().copy()
df_dominance_year.head(5)

# %%
df_melted_year_mallet = df_dominance_year.melt(id_vars= 'year' , value_vars=['Topic ' + str(i) for i in range(1, 7)], var_name='Topic', value_name='prevelance')

# %%
df_melted_year_mallet

# %%
df_melted_year_mallet.to_excel("/Users/yuanyuanli/Desktop/project_results/topic_trend_Umass.xlsx")

# %%
_ = sns.lineplot(data=df_melted_year_mallet, x="year", y="prevelance", hue="Topic", style="Topic", palette='Dark2')

# %% [markdown]
# ### Topic Distribution across different country

# %%
df_un.country.reset_index(drop = True)

# %%
df_weights["country"] = df_un.country.reset_index(drop = True)

# %%
df_weights

# %%
df_country = df_weights.groupby(['country', 'year'])['prevalent'].value_counts(normalize=True).unstack().fillna(0)
df_country

# %%
df_country.reset_index(inplace=True)

# %%
df_country

# %%
## Change the year

# %%
df_melted = df_country.melt(id_vars=['country', 'year'], value_vars=['Topic ' + str(i) for i in range(1,7)], 
                            var_name='Topic', value_name='prevalence')

# %%
df_melted

# %%
sns.relplot(x='year', y="prevalence", col="country", col_wrap=3, hue='Topic',
data=df_melted,
kind="line",
height=10,
style="Topic",
dashes=False,
ci=None,
palette = 'Dark2');

# %% [markdown]
# ## Stacked Area Visualization

# %%
df_country

# %%
df_country.set_index(['country', 'year'], inplace=True)

# %%
# set the figure size
plt.rcParams['figure.figsize'] = [10, 6]

# %%
for j in df_country.index.levels[0]:
  df_country.xs(j, level=0).plot.area(colormap='tab20')
  plt.title(j)
  plt.legend(loc='upper left')

plt.show()
